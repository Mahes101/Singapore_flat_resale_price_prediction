# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv("C:/Users/mahes/OneDrive/Desktop/singapore flat resale/singapore.csv")
# Out:
# C:\Users\mahes\AppData\Local\Temp\ipykernel_18624\1090075818.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("C:/Users/mahes/OneDrive/Desktop/singapore flat resale/singapore.csv")

# %%
data
# Out:
#           month        town         flat_type block       street_name  \
# 0       1990-01  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 1       1990-01  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 2       1990-01  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 3       1990-01  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 4       1990-01  ANG MO KIO            3 ROOM   216  ANG MO KIO AVE 1
# ...         ...         ...               ...   ...               ...
# 925884  2024-04      YISHUN         EXECUTIVE   826      YISHUN ST 81
# 925885  2024-04      YISHUN         EXECUTIVE   836      YISHUN ST 81
# 925886  2024-05      YISHUN         EXECUTIVE   834      YISHUN ST 81
# 925887  2024-02      YISHUN  MULTI-GENERATION   666      YISHUN AVE 4
# 925888  2024-03      YISHUN  MULTI-GENERATION   666      YISHUN AVE 4
#
#        storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# 0          10 TO 12            31.0          IMPROVED                 1977
# 1          04 TO 06            31.0          IMPROVED                 1977
# 2          10 TO 12            31.0          IMPROVED                 1977
# 3          07 TO 09            31.0          IMPROVED                 1977
# 4          04 TO 06            73.0    NEW GENERATION                 1976
# ...             ...             ...               ...                  ...
# 925884     04 TO 06           146.0        Maisonette                 1988
# 925885     04 TO 06           142.0         Apartment                 1988
# 925886     04 TO 06           154.0        Maisonette                 1988
# 925887     04 TO 06           164.0  Multi Generation                 1987
# 925888     10 TO 12           164.0  Multi Generation                 1987
#
#                  remaining  resale_price
# 0                      NaN        9000.0
# 1                      NaN        6000.0
# 2                      NaN        8000.0
# 3                      NaN        6000.0
# 4                      NaN       47200.0
# ...                    ...           ...
# 925884  62 years 10 months      900000.0
# 925885  62 years 10 months      805000.0
# 925886  62 years 09 months      948000.0
# 925887  62 years 11 months      998000.0
# 925888  62 years 09 months     1200000.0
#
# [925889 rows x 11 columns]

# %%
#convering data into dataframe
df=pd.DataFrame(data)
df.head(5)
# Out:
#      month        town flat_type block       street_name storey_range  \
# 0  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4  1990-01  ANG MO KIO    3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
#
#    floor_area_sqm      flat_model  lease_commence_date remaining  resale_price
# 0            31.0        IMPROVED                 1977       NaN        9000.0
# 1            31.0        IMPROVED                 1977       NaN        6000.0
# 2            31.0        IMPROVED                 1977       NaN        8000.0
# 3            31.0        IMPROVED                 1977       NaN        6000.0
# 4            73.0  NEW GENERATION                 1976       NaN       47200.0

# %%
#analyzing data-information 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 925889 entries, 0 to 925888
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   month                925889 non-null  object
#  1   town                 925889 non-null  object
#  2   flat_type            925889 non-null  object
#  3   block                925889 non-null  object
#  4   street_name          925889 non-null  object
#  5   storey_range         925889 non-null  object
#  6   floor_area_sqm       925889 non-null  float64
#  7   flat_model           925889 non-null  object
#  8   lease_commence_date  925889 non-null  int64
#  9   remaining            216839 non-null  object
#  10  resale_price         925889 non-null  float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 77.7+ MB

# %%
df.shape
# Out:
# (925889, 11)

# %%
df.describe()
# Out:
#        floor_area_sqm  lease_commence_date  resale_price
# count   925889.000000        925889.000000  9.258890e+05
# mean        95.691674          1988.262199  3.203630e+05
# std         25.826845            10.648340  1.700844e+05
# min         28.000000          1966.000000  5.000000e+03
# 25%         73.000000          1981.000000  1.930000e+05
# 50%         93.000000          1986.000000  2.970000e+05
# 75%        113.000000          1996.000000  4.170000e+05
# max        307.000000          2022.000000  1.568888e+06

# %%
df.columns
# Out:
# Index(['month', 'town', 'flat_type', 'block', 'street_name', 'storey_range',
#        'floor_area_sqm', 'flat_model', 'lease_commence_date', 'remaining',
#        'resale_price'],
#       dtype='object')

# %%
#handling missing values
df.isnull().sum()
# Out:
# month                       0
# town                        0
# flat_type                   0
# block                       0
# street_name                 0
# storey_range                0
# floor_area_sqm              0
# flat_model                  0
# lease_commence_date         0
# remaining              709050
# resale_price                0
# dtype: int64

# %%
df.nunique()
# Out:
# month                   413
# town                     27
# flat_type                 8
# block                  2708
# street_name             584
# storey_range             25
# floor_area_sqm          212
# flat_model               34
# lease_commence_date      56
# remaining               771
# resale_price           9498
# dtype: int64

# %%
#unique value of flat_type
df['flat_type'].unique()
# Out:
# array(['1 ROOM', '3 ROOM', '4 ROOM', '5 ROOM', '2 ROOM', 'EXECUTIVE',
#        'MULTI GENERATION', 'MULTI-GENERATION'], dtype=object)

# %%
flat_type_mappings ={Type : 'MULTI GENERATION' if Type == 'MULTI-GENERATION'  else Type  for Type in df['flat_type']}

df['flat_type'] = df['flat_type'].map(flat_type_mappings)
df['flat_type'].value_counts()
# Out:
# 4 ROOM              351846
# 3 ROOM              295649
# 5 ROOM              195167
# EXECUTIVE            69584
# 2 ROOM               11796
# 1 ROOM                1304
# MULTI GENERATION       543
# Name: flat_type, dtype: int64

# %%
df['flat_model'].nunique()
# Out:
# 34

# %%
flat_model_mappings = {model : model.upper()  for model in df['flat_model']}

df['flat_model'] = df['flat_model'].map(flat_model_mappings)

df['flat_model'].nunique()
# Out:
# 21

# %%
#month column converted with only day.
df['month'] = pd.to_datetime(df['month'], format = '%Y-%m').dt.to_period('M')

# %%
df['year'] = df['month'].dt.year
df['month'] = df['month'].dt.month

# %%
# Extract the minimum storey and maximum storey from 'storey_range' and convert it to integer

df['minimum_storey']=df['storey_range'].str.split(' TO ').str[0].astype(int)
df['maximum_storey']=df['storey_range'].str.split(' TO ').str[1].astype(int)
df.head()
# Out:
#    month        town flat_type block       street_name storey_range  \
# 0      1  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1      1  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2      1  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3      1  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4      1  ANG MO KIO    3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
#
#    floor_area_sqm      flat_model  lease_commence_date remaining  \
# 0            31.0        IMPROVED                 1977       NaN
# 1            31.0        IMPROVED                 1977       NaN
# 2            31.0        IMPROVED                 1977       NaN
# 3            31.0        IMPROVED                 1977       NaN
# 4            73.0  NEW GENERATION                 1976       NaN
#
#    resale_price  year  minimum_storey  maximum_storey
# 0        9000.0  1990              10              12
# 1        6000.0  1990               4               6
# 2        8000.0  1990              10              12
# 3        6000.0  1990               7               9
# 4       47200.0  1990               4               6

# %%
df['is_remaining_lease'] = np.where(df['remaining'].isna()==True, 0, 1)

# %%
df['remaining'] = np.where(df['remaining'].isna()==True, 'Not Specified', df['remaining'])

# %%
df.isna().sum()
# Out:
# month                  0
# town                   0
# flat_type              0
# block                  0
# street_name            0
# storey_range           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# remaining              0
# resale_price           0
# year                   0
# minimum_storey         0
# maximum_storey         0
# is_remaining_lease     0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
#univariate analysis 
#analysing categorical variables using countplot
plt.figure(figsize=(15,8))
ax = sns.countplot(data=df,x=df.flat_type)
ax.set_title("Flat_type")
# Out:
# Text(0.5, 1.0, 'Flat_type')

# %%
plt.figure(figsize=(15,8))
ax = sns.countplot(data=df,x=df.storey_range)
ax.set_title("storey_range")
# Out:
# Text(0.5, 1.0, 'storey_range')

# %%
#univariate analysis 
#analysing numerical variables using boxplot
plt.figure(figsize=(10,8))
ax = sns.boxplot(data=df,x=df.resale_price)
ax.set_title("resale_price")
# Out:
# Text(0.5, 1.0, 'resale_price')

# %%
ax = sns.violinplot(data=df,x=df.resale_price)
ax.set_title("resale_price")
# Out:
# Text(0.5, 1.0, 'resale_price')

# %%
#analysing numerical variables using boxplot
plt.figure(figsize=(10,8))
ax = sns.boxplot(data=df,x=df.minimum_storey)
ax.set_title("minimum_storey")
# Out:
# Text(0.5, 1.0, 'minimum_storey')

# %%
#analysing numerical variables using boxplot
plt.figure(figsize=(10,8))
ax = sns.boxplot(data=df,x=df.maximum_storey)
ax.set_title("maximum_storey")
# Out:
# Text(0.5, 1.0, 'maximum_storey')

# %%
import seaborn as sns
sns.histplot(df, x="floor_area_sqm", binwidth=18)
# Out:
# <Axes: xlabel='floor_area_sqm', ylabel='Count'>

# %%
#bivariate analysis -numerical variable
sns.relplot(
    data=df, x="maximum_storey", y="minimum_storey")

# %%
#bivariate analysis -numerical variable
sns.scatterplot(
    data=df, x="floor_area_sqm", y="resale_price")
# Out:
# <Axes: xlabel='floor_area_sqm', ylabel='resale_price'>

# %%
categorical_cols=df.select_dtypes(include=['object']).columns
numumerical_cols = df.select_dtypes(include=np.number).columns.tolist()
print(categorical_cols)
print(numumerical_cols)
# Out:
# Index(['town', 'flat_type', 'block', 'street_name', 'storey_range',
#        'flat_model', 'remaining'],
#       dtype='object')
# ['month', 'floor_area_sqm', 'lease_commence_date', 'resale_price', 'year', 'minimum_storey', 'maximum_storey', 'is_remaining_lease']

# %%
for resale_price in numumerical_cols:

    print('Skew :', round(df[resale_price].skew(), 2))
    plt.figure(figsize = (15, 4))
    plt.subplot(1, 2, 1)
    df[resale_price].hist(grid=False)
    plt.ylabel('count')
    plt.subplot(1, 2, 2)
    sns.boxplot(x=df[resale_price])
    plt.show()
# Out:
# Skew : -0.03
# Skew : 0.37
# Skew : 0.65
# Skew : 0.94
# Skew : 0.29
# Skew : 1.35
# Skew : 1.35
# Skew : 1.26

# %%
#Plotting a pair plot for bivariate analysis
g = sns.PairGrid(df,vars=['floor_area_sqm','resale_price','maximum_storey','minimum_storey','year'])
#setting color
g.map_upper(sns.scatterplot, color='crimson')
g.map_lower(sns.scatterplot, color='limegreen')
g.map_diag(plt.hist, color='orange')
#show figure
plt.show()

# %%
# Generate a heatmap to visualize the correlation matrix for the specified columns
column_name = ['month', 'year', 'floor_area_sqm', 'lease_commence_date', 'minimum_storey','maximum_storey',
               'is_remaining_lease', 'resale_price']
sns.heatmap(df[column_name].corr(), annot= True)
# Out:
# <Axes: >

# %%
import seaborn as sns
from scipy.stats import skew

# %%
def skewness_plot(df, *column):
    nrow = len(column)
    plot_no=0
    for col_name in column:
        if  'sqrt' in col_name:
            title= "After Treatment"
        else:
            title = "Before Treatment"

        plt.figure(figsize=(16, 8))

        plot_no+=1
        plt.subplot(nrow, 3, plot_no)
        sns.boxplot(x=col_name, data=df)
        plt.title('Boxplot - '+ title)

        plot_no+=1
        plt.subplot(nrow, 3, plot_no)
        sns.histplot(df[col_name])
        plt.title(f'histplot - Skewness: {skew(df[col_name])}')

        plot_no+=1
        plt.subplot(nrow, 3, plot_no)
        sns.violinplot(x=col_name, data=df)
        plt.title('Violinplot - ' + title)

    plt.tight_layout()
    
    return plt.show()

# %%
numerical_columns = ['floor_area_sqm', 'resale_price']
skewness_plot(df, *numerical_columns)

# %%
def Square_Root_Transformation(df, *column):

    for col_name in column:
        # Square Root Tansformation
        df[col_name+'_sqrt'] = np.sqrt(df[col_name])
        

    column =[i for i in df.columns if 'sqrt' in i]

    return skewness_plot(df, * column)

# %%
Square_Root_Transformation(df, *numerical_columns)

# %%
# Generate a heatmap to visualize the correlation matrix for the specified columns
column_name = ['month', 'year', 'floor_area_sqm', 'floor_area_sqm_sqrt', 'lease_commence_date', 'minimum_storey','maximum_storey',
               'is_remaining_lease', 'resale_price', 'resale_price_sqrt']
sns.heatmap(df[column_name].corr(), annot= True)
# Out:
# <Axes: >

# %%
df
# Out:
#         month        town         flat_type block       street_name  \
# 0           1  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 1           1  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 2           1  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 3           1  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 4           1  ANG MO KIO            3 ROOM   216  ANG MO KIO AVE 1
# ...       ...         ...               ...   ...               ...
# 925884      4      YISHUN         EXECUTIVE   826      YISHUN ST 81
# 925885      4      YISHUN         EXECUTIVE   836      YISHUN ST 81
# 925886      5      YISHUN         EXECUTIVE   834      YISHUN ST 81
# 925887      2      YISHUN  MULTI GENERATION   666      YISHUN AVE 4
# 925888      3      YISHUN  MULTI GENERATION   666      YISHUN AVE 4
#
#        storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# 0          10 TO 12            31.0          IMPROVED                 1977
# 1          04 TO 06            31.0          IMPROVED                 1977
# 2          10 TO 12            31.0          IMPROVED                 1977
# 3          07 TO 09            31.0          IMPROVED                 1977
# 4          04 TO 06            73.0    NEW GENERATION                 1976
# ...             ...             ...               ...                  ...
# 925884     04 TO 06           146.0        MAISONETTE                 1988
# 925885     04 TO 06           142.0         APARTMENT                 1988
# 925886     04 TO 06           154.0        MAISONETTE                 1988
# 925887     04 TO 06           164.0  MULTI GENERATION                 1987
# 925888     10 TO 12           164.0  MULTI GENERATION                 1987
#
#                  remaining  resale_price  year  minimum_storey  \
# 0            Not Specified        9000.0  1990              10
# 1            Not Specified        6000.0  1990               4
# 2            Not Specified        8000.0  1990              10
# 3            Not Specified        6000.0  1990               7
# 4            Not Specified       47200.0  1990               4
# ...                    ...           ...   ...             ...
# 925884  62 years 10 months      900000.0  2024               4
# 925885  62 years 10 months      805000.0  2024               4
# 925886  62 years 09 months      948000.0  2024               4
# 925887  62 years 11 months      998000.0  2024               4
# 925888  62 years 09 months     1200000.0  2024              10
#
#         maximum_storey  is_remaining_lease  floor_area_sqm_sqrt  \
# 0                   12                   0             5.567764
# 1                    6                   0             5.567764
# 2                   12                   0             5.567764
# 3                    9                   0             5.567764
# 4                    6                   0             8.544004
# ...                ...                 ...                  ...
# 925884               6                   1            12.083046
# 925885               6                   1            11.916375
# 925886               6                   1            12.409674
# 925887               6                   1            12.806248
# 925888              12                   1            12.806248
#
#         resale_price_sqrt
# 0               94.868330
# 1               77.459667
# 2               89.442719
# 3               77.459667
# 4              217.255610
# ...                   ...
# 925884         948.683298
# 925885         897.217922
# 925886         973.652916
# 925887         998.999499
# 925888        1095.445115
#
# [925889 rows x 17 columns]

# %%
df.to_csv("singapore.csv")

# %%
def outlier_plot(df):

    plt.figure(figsize=(16, 10))

    plt.subplot(2, 2, 1)
    sns.boxplot(x='floor_area_sqm', data=df)
    plt.title('Boxplot - floor area sqm')

    plt.subplot(2, 2, 2)
    sns.boxplot(x='floor_area_sqm_sqrt', data=df)
    plt.title('Boxplot - floor area sqm sqrt')

    plt.subplot(2, 2, 3)
    sns.boxplot(x='resale_price', data=df)
    plt.title('Boxplot - '+ 'resale price')

    plt.subplot(2, 2, 4)
    sns.boxplot(x='resale_price_sqrt', data=df)
    plt.title('Boxplot - '+ 'resale price sqrt')
    plt.tight_layout()
    
    return plt.show()
outlier_plot(df)

# %%
def outlier_quantile(df, *column):

    for col_name in column:
        #Finding the IQR
        percentile25 = df[col_name].quantile(0.25)
        percentile75 = df[col_name].quantile(0.75)
        iqr = percentile75 - percentile25

        # Define upper and lower limits for outlier detection
        upper_limit = percentile75 + 1.5 * iqr
        lower_limit = percentile25 - 1.5 * iqr

        # Cap values beyond upper and lower limits
        df[col_name] = np.where(df[col_name] > upper_limit, upper_limit, df[col_name])
        df[col_name] = np.where(df[col_name] < lower_limit, lower_limit, df[col_name])

    return outlier_plot(df)

# %%
column_name = [ 'floor_area_sqm', 'floor_area_sqm_sqrt', 'resale_price', 'resale_price_sqrt']
outlier_quantile(df, *column_name)

# %%
column_name = ['month', 'year', 'floor_area_sqm', 'floor_area_sqm_sqrt', 'lease_commence_date', 'minimum_storey','maximum_storey',
               'is_remaining_lease', 'resale_price', 'resale_price_sqrt']
sns.heatmap(df[column_name].corr(), annot= True)
# Out:
# <Axes: >

# %%
df1 = df.copy()
df1['remaining'] = df1['remaining'].astype(str)
df1
# Out:
#         month        town         flat_type block       street_name  \
# 0           1  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 1           1  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 2           1  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 3           1  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 4           1  ANG MO KIO            3 ROOM   216  ANG MO KIO AVE 1
# ...       ...         ...               ...   ...               ...
# 925884      4      YISHUN         EXECUTIVE   826      YISHUN ST 81
# 925885      4      YISHUN         EXECUTIVE   836      YISHUN ST 81
# 925886      5      YISHUN         EXECUTIVE   834      YISHUN ST 81
# 925887      2      YISHUN  MULTI GENERATION   666      YISHUN AVE 4
# 925888      3      YISHUN  MULTI GENERATION   666      YISHUN AVE 4
#
#        storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# 0          10 TO 12            31.0          IMPROVED                 1977
# 1          04 TO 06            31.0          IMPROVED                 1977
# 2          10 TO 12            31.0          IMPROVED                 1977
# 3          07 TO 09            31.0          IMPROVED                 1977
# 4          04 TO 06            73.0    NEW GENERATION                 1976
# ...             ...             ...               ...                  ...
# 925884     04 TO 06           146.0        MAISONETTE                 1988
# 925885     04 TO 06           142.0         APARTMENT                 1988
# 925886     04 TO 06           154.0        MAISONETTE                 1988
# 925887     04 TO 06           164.0  MULTI GENERATION                 1987
# 925888     10 TO 12           164.0  MULTI GENERATION                 1987
#
#                  remaining  resale_price  year  minimum_storey  \
# 0            Not Specified        9000.0  1990              10
# 1            Not Specified        6000.0  1990               4
# 2            Not Specified        8000.0  1990              10
# 3            Not Specified        6000.0  1990               7
# 4            Not Specified       47200.0  1990               4
# ...                    ...           ...   ...             ...
# 925884  62 years 10 months      753000.0  2024               4
# 925885  62 years 10 months      753000.0  2024               4
# 925886  62 years 09 months      753000.0  2024               4
# 925887  62 years 11 months      753000.0  2024               4
# 925888  62 years 09 months      753000.0  2024              10
#
#         maximum_storey  is_remaining_lease  floor_area_sqm_sqrt  \
# 0                   12                   0             5.567764
# 1                    6                   0             5.567764
# 2                   12                   0             5.567764
# 3                    9                   0             5.567764
# 4                    6                   0             8.544004
# ...                ...                 ...                  ...
# 925884               6                   1            12.083046
# 925885               6                   1            11.916375
# 925886               6                   1            12.409674
# 925887               6                   1            12.806248
# 925888              12                   1            12.806248
#
#         resale_price_sqrt
# 0              129.661074
# 1              129.661074
# 2              129.661074
# 3              129.661074
# 4              217.255610
# ...                   ...
# 925884         948.683298
# 925885         897.217922
# 925886         955.411950
# 925887         955.411950
# 925888         955.411950
#
# [925889 rows x 17 columns]

# %%
df1.to_csv('singapore1.csv', index=False)

# %%
df1.dtypes
# Out:
# month                    int64
# town                    object
# flat_type               object
# block                   object
# street_name             object
# storey_range            object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# remaining               object
# resale_price           float64
# year                     int64
# minimum_storey           int32
# maximum_storey           int32
# is_remaining_lease       int32
# floor_area_sqm_sqrt    float64
# resale_price_sqrt      float64
# dtype: object

# %%
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()

# Specify categorical column names for ordinal encoding
column_names = ['town', 'flat_type', 'block', 'street_name', 'storey_range', 'flat_model', 'remaining']

# Dictionary to store unique values before and after ordinal encoding
unique_value ={}
for col_name in column_names:
    data = df1[col_name].unique()
    data.sort()

    df1[col_name] = enc.fit_transform(df1[[col_name]])

    globals()[col_name] = {}
    for i in df1[col_name].unique():
        globals()[col_name][data[int(i)]] = i
        unique_value[f'{col_name}'] = globals()[col_name]
    # print(globals()[col_name])
unique_value
# Out:
# {'town': {'ANG MO KIO': 0.0,
#   'BEDOK': 1.0,
#   'BISHAN': 2.0,
#   'BUKIT BATOK': 3.0,
#   'BUKIT MERAH': 4.0,
#   'BUKIT TIMAH': 6.0,
#   'CENTRAL AREA': 7.0,
#   'CHOA CHU KANG': 8.0,
#   'CLEMENTI': 9.0,
#   'GEYLANG': 10.0,
#   'HOUGANG': 11.0,
#   'JURONG EAST': 12.0,
#   'JURONG WEST': 13.0,
#   'KALLANG/WHAMPOA': 14.0,
#   'MARINE PARADE': 16.0,
#   'QUEENSTOWN': 19.0,
#   'SENGKANG': 21.0,
#   'SERANGOON': 22.0,
#   'TAMPINES': 23.0,
#   'TOA PAYOH': 24.0,
#   'WOODLANDS': 25.0,
#   'YISHUN': 26.0,
#   'LIM CHU KANG': 15.0,
#   'SEMBAWANG': 20.0,
#   'BUKIT PANJANG': 5.0,
#   'PASIR RIS': 17.0,
#   'PUNGGOL': 18.0},
#  'flat_type': {'1 ROOM': 0.0,
#   '3 ROOM': 2.0,
#   '4 ROOM': 3.0,
#   '5 ROOM': 4.0,
#   '2 ROOM': 1.0,
#   'EXECUTIVE': 5.0,
#   'MULTI GENERATION': 6.0},
#  'block': {'309': 829.0,
#   '216': 447.0,
#   '211': 430.0,
#   '202': 388.0,
#   '235': 532.0,
#   '232': 521.0,
#   '308': 825.0,
#   '220': 468.0,
#   '219': 462.0,
#   '247': 548.0,
#   '320': 883.0,
#   '252': 558.0,
#   '223': 478.0,
#   '230': 509.0,
#   '329': 921.0,
#   '313': 849.0,
#   '117': 79.0,
#   '110': 53.0,
#   '343': 981.0,
#   '345': 983.0,
#   '346': 984.0,
#   '121': 99.0,
#   '129': 135.0,
#   '130': 143.0,
#   '128': 130.0,
#   '127': 126.0,
#   '126': 121.0,
#   '403': 1109.0,
#   '404': 1114.0,
#   '405': 1117.0,
#   '417': 1160.0,
#   '418': 1162.0,
#   '419': 1166.0,
#   '441': 1239.0,
#   '442': 1244.0,
#   '443': 1249.0,
#   '444': 1254.0,
#   '450': 1273.0,
#   '435': 1213.0,
#   '433': 1207.0,
#   '434': 1210.0,
#   '424': 1172.0,
#   '425': 1177.0,
#   '466': 1321.0,
#   '471': 1343.0,
#   '474': 1356.0,
#   '570': 1665.0,
#   '586': 1695.0,
#   '455': 1293.0,
#   '465': 1320.0,
#   '463': 1315.0,
#   '564': 1658.0,
#   '560': 1651.0,
#   '558': 1648.0,
#   '559': 1649.0,
#   '538': 1613.0,
#   '534': 1608.0,
#   '601': 1727.0,
#   '603': 1736.0,
#   '604': 1740.0,
#   '608': 1755.0,
#   '611': 1759.0,
#   '505': 1500.0,
#   '503': 1491.0,
#   '610': 1758.0,
#   '607': 1754.0,
#   '524': 1576.0,
#   '513': 1534.0,
#   '643': 1869.0,
#   '542': 1618.0,
#   '548': 1631.0,
#   '550': 1638.0,
#   '639': 1854.0,
#   '637': 1845.0,
#   '330': 925.0,
#   '333': 936.0,
#   '156': 191.0,
#   '152': 186.0,
#   '178': 277.0,
#   '180': 286.0,
#   '209': 421.0,
#   '231': 518.0,
#   '254': 561.0,
#   '103': 13.0,
#   '105': 22.0,
#   '344': 982.0,
#   '324': 902.0,
#   '120': 94.0,
#   '124': 116.0,
#   '414': 1149.0,
#   '438': 1224.0,
#   '427': 1183.0,
#   '428': 1184.0,
#   '473': 1351.0,
#   '573': 1676.0,
#   '585': 1694.0,
#   '456': 1297.0,
#   '544': 1620.0,
#   '640': 1858.0,
#   '638': 1850.0,
#   '646': 1873.0,
#   '150': 183.0,
#   '179': 282.0,
#   '336': 950.0,
#   '335': 946.0,
#   '401': 1107.0,
#   '439': 1228.0,
#   '430': 1192.0,
#   '460': 1302.0,
#   '459': 1300.0,
#   '716': 2137.0,
#   '545': 1621.0,
#   '620': 1797.0,
#   '622': 1799.0,
#   '259': 577.0,
#   '101': 3.0,
#   '18': 285.0,
#   '28': 686.0,
#   '29': 734.0,
#   '30': 790.0,
#   '75': 2184.0,
#   '76': 2198.0,
#   '501': 1481.0,
#   '502': 1486.0,
#   '504': 1495.0,
#   '2': 376.0,
#   '20': 377.0,
#   '21': 425.0,
#   '59': 1707.0,
#   '58': 1688.0,
#   '55': 1637.0,
#   '22': 467.0,
#   '104': 17.0,
#   '107': 32.0,
#   '69': 2070.0,
#   '33': 924.0,
#   '46': 1301.0,
#   '116': 75.0,
#   '115': 70.0,
#   '125': 120.0,
#   '138': 157.0,
#   '87': 2456.0,
#   '100': 2.0,
#   '412': 1143.0,
#   '402': 1108.0,
#   '416': 1156.0,
#   '136': 155.0,
#   '529': 1598.0,
#   '510': 1523.0,
#   '525': 1580.0,
#   '218': 457.0,
#   '213': 439.0,
#   '532': 1606.0,
#   '533': 1607.0,
#   '536': 1611.0,
#   '537': 1612.0,
#   '44': 1233.0,
#   '540': 1616.0,
#   '702': 2119.0,
#   '615': 1773.0,
#   '712': 2133.0,
#   '50': 1479.0,
#   '54': 1615.0,
#   '606': 1749.0,
#   '616': 1777.0,
#   '15': 182.0,
#   '34': 970.0,
#   '36': 1032.0,
#   '35': 994.0,
#   '41': 1135.0,
#   '42': 1167.0,
#   '53': 1599.0,
#   '51': 1522.0,
#   '8': 2287.0,
#   '718': 2141.0,
#   '724': 2148.0,
#   '166': 226.0,
#   '71': 2130.0,
#   '82': 2361.0,
#   '78': 2223.0,
#   '79': 2268.0,
#   '80': 2288.0,
#   '134': 153.0,
#   '132': 150.0,
#   '131': 146.0,
#   '133': 151.0,
#   '89': 2500.0,
#   '62': 1796.0,
#   '422': 1170.0,
#   '507': 1509.0,
#   '508': 1514.0,
#   '517': 1546.0,
#   '95': 2610.0,
#   '93': 2579.0,
#   '43': 1191.0,
#   '543': 1619.0,
#   '547': 1626.0,
#   '708': 2125.0,
#   '707': 2124.0,
#   '713': 2134.0,
#   '609': 1756.0,
#   '61': 1757.0,
#   '56': 1650.0,
#   '165': 223.0,
#   '710': 2131.0,
#   '613': 1765.0,
#   '602': 1732.0,
#   '605': 1744.0,
#   '112': 61.0,
#   '1': 0.0,
#   '722': 2146.0,
#   '72': 2143.0,
#   '31': 835.0,
#   '111': 58.0,
#   '118': 83.0,
#   '96': 2624.0,
#   '137': 156.0,
#   '139': 162.0,
#   '725': 2149.0,
#   '24': 540.0,
#   '304': 807.0,
#   '310': 836.0,
#   '160': 205.0,
#   '161': 208.0,
#   '164': 219.0,
#   '177': 276.0,
#   '205': 403.0,
#   '248': 549.0,
#   '258': 572.0,
#   '4': 1105.0,
#   '6': 1725.0,
#   '146': 176.0,
#   '143': 173.0,
#   '145': 175.0,
#   '182': 294.0,
#   '228': 503.0,
#   '227': 498.0,
#   '244': 545.0,
#   '113': 64.0,
#   '163': 215.0,
#   '169': 239.0,
#   '204': 398.0,
#   '477': 1367.0,
#   '527': 1589.0,
#   '535': 1609.0,
#   '484': 1378.0,
#   '491': 1413.0,
#   '481': 1375.0,
#   '217': 452.0,
#   '448': 1265.0,
#   '446': 1258.0,
#   '447': 1262.0,
#   '554': 1644.0,
#   '551': 1641.0,
#   '458': 1299.0,
#   '436': 1217.0,
#   '452': 1284.0,
#   '539': 1614.0,
#   '198': 363.0,
#   '203': 392.0,
#   '407': 1125.0,
#   '469': 1334.0,
#   '468': 1329.0,
#   '801': 2290.0,
#   '97': 2637.0,
#   '11': 52.0,
#   '68': 2017.0,
#   '94': 2595.0,
#   '14': 165.0,
#   '84': 2388.0,
#   '83': 2375.0,
#   '52': 1561.0,
#   '807': 2313.0,
#   '461': 1305.0,
#   '32': 882.0,
#   '171': 248.0,
#   '173': 256.0,
#   '88': 2476.0,
#   '86': 2432.0,
#   '74': 2166.0,
#   '25': 551.0,
#   '267': 618.0,
#   '269': 627.0,
#   '924': 2571.0,
#   '925': 2572.0,
#   '817': 2350.0,
#   '818': 2354.0,
#   '808': 2317.0,
#   '809': 2322.0,
#   '285': 699.0,
#   '287': 709.0,
#   '274': 656.0,
#   '291': 743.0,
#   '293': 753.0,
#   '262': 594.0,
#   '914': 2559.0,
#   '250': 552.0,
#   '226': 492.0,
#   '236': 533.0,
#   '270': 637.0,
#   '420': 1168.0,
#   '157': 192.0,
#   '820': 2362.0,
#   '819': 2358.0,
#   '813': 2339.0,
#   '810': 2329.0,
#   '266': 613.0,
#   '265': 607.0,
#   '286': 704.0,
#   '272': 646.0,
#   '275': 661.0,
#   '295': 760.0,
#   '261': 589.0,
#   '913': 2558.0,
#   '910': 2555.0,
#   '253': 559.0,
#   '277': 671.0,
#   '928': 2575.0,
#   '832': 2379.0,
#   '838': 2385.0,
#   '839': 2386.0,
#   '159': 202.0,
#   '812': 2335.0,
#   '811': 2332.0,
#   '294': 758.0,
#   '432': 1202.0,
#   '816': 2347.0,
#   '289': 722.0,
#   '298': 775.0,
#   '912': 2557.0,
#   '278': 676.0,
#   '279': 680.0,
#   '245': 546.0,
#   '149': 179.0,
#   '148': 178.0,
#   '91': 2554.0,
#   '27': 636.0,
#   '85A': 2429.0,
#   '85B': 2430.0,
#   '206': 407.0,
#   '193': 343.0,
#   '200': 378.0,
#   '1A': 369.0,
#   '162': 211.0,
#   '701': 2118.0,
#   '736': 2161.0,
#   '742': 2169.0,
#   '276': 666.0,
#   '751': 2186.0,
#   '752': 2187.0,
#   '733': 2158.0,
#   '740': 2167.0,
#   '280': 687.0,
#   '772': 2214.0,
#   '229': 507.0,
#   '238': 536.0,
#   '255': 562.0,
#   '256': 563.0,
#   '328': 920.0,
#   '348': 988.0,
#   '571': 1669.0,
#   '584': 1693.0,
#   '454': 1292.0,
#   '575': 1683.0,
#   '561': 1653.0,
#   '512': 1530.0,
#   '523': 1571.0,
#   '644': 1870.0,
#   '621': 1798.0,
#   '625': 1811.0,
#   '155': 190.0,
#   '470': 1339.0,
#   '565': 1659.0,
#   '546': 1622.0,
#   '612': 1760.0,
#   '648': 1875.0,
#   '867A': 2448.0,
#   '395': 1095.0,
#   '396': 1096.0,
#   '822': 2364.0,
#   '863B': 2442.0,
#   '487A': 1393.0,
#   '886': 2484.0,
#   '873': 2464.0,
#   '670': 1973.0,
#   '899': 2535.0,
#   '898A': 2533.0,
#   '355A': 1018.0,
#   '692': 2083.0,
#   '978': 2646.0,
#   '897A': 2529.0,
#   '887': 2489.0,
#   '863A': 2441.0,
#   '133A': 152.0,
#   '939': 2592.0,
#   '905': 2547.0,
#   '927': 2574.0,
#   '861A': 2437.0,
#   '894': 2515.0,
#   '350A': 996.0,
#   '679': 2013.0,
#   '936': 2589.0,
#   '919': 2564.0,
#   '894A': 2516.0,
#   '899A': 2536.0,
#   '896': 2524.0,
#   '886A': 2485.0,
#   '188': 319.0,
#   '923': 2570.0,
#   '201A': 383.0,
#   '888': 2493.0,
#   '494C': 1435.0,
#   '895A': 2521.0,
#   '896A': 2525.0,
#   '938': 2591.0,
#   '654': 1899.0,
#   '943': 2599.0,
#   '940': 2596.0,
#   '942': 2598.0,
#   '398': 1098.0,
#   '769': 2209.0,
#   '966': 2631.0,
#   '945': 2601.0,
#   '889': 2495.0,
#   '941': 2597.0,
#   '795A': 2275.0,
#   '947': 2603.0,
#   '889A': 2496.0,
#   '871A': 2460.0,
#   '887A': 2490.0,
#   '946': 2602.0,
#   '874A': 2466.0,
#   '918': 2563.0,
#   '888A': 2494.0,
#   '869': 2453.0,
#   '976': 2644.0,
#   '979': 2649.0,
#   '567': 1661.0,
#   '485B': 1385.0,
#   '10F': 51.0,
#   '150A': 184.0,
#   '948': 2604.0,
#   '230C': 511.0,
#   '230J': 517.0,
#   '43A': 1232.0,
#   '953': 2614.0,
#   '488A': 1397.0,
#   '491B': 1415.0,
#   '492C': 1424.0,
#   '486B': 1390.0,
#   '495E': 1446.0,
#   '789': 2267.0,
#   '980': 2654.0,
#   '823': 2365.0,
#   '974': 2642.0,
#   '489C': 1404.0,
#   '496B': 1448.0,
#   '217A': 453.0,
#   '965': 2630.0,
#   '975': 2643.0,
#   '880A': 2478.0,
#   '488B': 1398.0,
#   '495F': 1447.0,
#   '952': 2613.0,
#   '506B': 1507.0,
#   '496E': 1451.0,
#   '491F': 1419.0,
#   '94B': 2606.0,
#   '961': 2626.0,
#   '830A': 2377.0,
#   '842D': 2394.0,
#   '487B': 1394.0,
#   '491H': 1421.0,
#   ...},
#  'street_name': {'ANG MO KIO AVE 1': 13.0,
#   'ANG MO KIO AVE 3': 16.0,
#   'ANG MO KIO AVE 4': 17.0,
#   'ANG MO KIO AVE 10': 14.0,
#   'ANG MO KIO AVE 5': 18.0,
#   'ANG MO KIO AVE 8': 20.0,
#   'ANG MO KIO AVE 6': 19.0,
#   'ANG MO KIO AVE 9': 21.0,
#   'ANG MO KIO AVE 2': 15.0,
#   'BEDOK RESERVOIR RD': 45.0,
#   'BEDOK NTH ST 3': 42.0,
#   'BEDOK STH RD': 50.0,
#   'NEW UPP CHANGI RD': 340.0,
#   'BEDOK NTH RD': 39.0,
#   'BEDOK STH AVE 1': 47.0,
#   'CHAI CHEE RD': 115.0,
#   'CHAI CHEE DR': 114.0,
#   'BEDOK NTH AVE 4': 38.0,
#   'BEDOK STH AVE 3': 49.0,
#   'BEDOK STH AVE 2': 48.0,
#   'BEDOK NTH ST 2': 41.0,
#   'BEDOK NTH ST 4': 43.0,
#   'BEDOK NTH AVE 2': 36.0,
#   'BEDOK NTH AVE 3': 37.0,
#   'BEDOK NTH AVE 1': 35.0,
#   'BEDOK NTH ST 1': 40.0,
#   'CHAI CHEE ST': 116.0,
#   'SIN MING RD': 437.0,
#   'SHUNFU RD': 425.0,
#   'BT BATOK ST 11': 70.0,
#   'BT BATOK WEST AVE 8': 86.0,
#   'BT BATOK WEST AVE 6': 84.0,
#   'BT BATOK ST 21': 71.0,
#   'BT BATOK EAST AVE 5': 68.0,
#   'BT BATOK EAST AVE 4': 67.0,
#   'HILLVIEW AVE': 200.0,
#   'BT BATOK CTRL': 65.0,
#   'BT BATOK ST 31': 75.0,
#   'BT BATOK EAST AVE 3': 66.0,
#   'TAMAN HO SWEE': 448.0,
#   'TELOK BLANGAH CRES': 487.0,
#   'BEO CRES': 52.0,
#   'TELOK BLANGAH DR': 488.0,
#   'DEPOT RD': 166.0,
#   'TELOK BLANGAH RISE': 490.0,
#   'JLN BT MERAH': 236.0,
#   'HENDERSON RD': 199.0,
#   'INDUS RD': 228.0,
#   'BT MERAH VIEW': 90.0,
#   'HENDERSON CRES': 198.0,
#   'BT PURMEI RD': 92.0,
#   'TELOK BLANGAH HTS': 489.0,
#   'EVERTON PK': 178.0,
#   'KG BAHRU HILL': 292.0,
#   'REDHILL CL': 385.0,
#   'HOY FATT RD': 226.0,
#   'HAVELOCK RD': 197.0,
#   'JLN KLINIK': 241.0,
#   'JLN RUMAH TINGGI': 248.0,
#   'JLN BT HO SWEE': 235.0,
#   'KIM CHENG ST': 294.0,
#   'MOH GUAN TER': 335.0,
#   'TELOK BLANGAH WAY': 492.0,
#   'KIM TIAN RD': 299.0,
#   'KIM TIAN PL': 298.0,
#   'EMPRESS RD': 175.0,
#   "QUEEN'S RD": 382.0,
#   'FARRER RD': 181.0,
#   'JLN KUKOH': 242.0,
#   'OUTRAM PK': 345.0,
#   'SHORT ST': 424.0,
#   'SELEGIE RD': 397.0,
#   'UPP CROSS ST': 505.0,
#   'WATERLOO ST': 510.0,
#   'QUEEN ST': 380.0,
#   'BUFFALO RD': 97.0,
#   'ROWELL RD': 393.0,
#   'ROCHOR RD': 392.0,
#   'BAIN ST': 30.0,
#   'SMITH ST': 438.0,
#   'VEERASAMY RD': 509.0,
#   'TECK WHYE AVE': 484.0,
#   'TECK WHYE LANE': 486.0,
#   'CLEMENTI AVE 3': 143.0,
#   'WEST COAST DR': 512.0,
#   'CLEMENTI AVE 2': 142.0,
#   'CLEMENTI AVE 5': 145.0,
#   'CLEMENTI AVE 4': 144.0,
#   'CLEMENTI AVE 1': 141.0,
#   'WEST COAST RD': 513.0,
#   'CLEMENTI WEST ST 1': 151.0,
#   'CLEMENTI WEST ST 2': 152.0,
#   'CLEMENTI ST 13': 149.0,
#   "C'WEALTH AVE WEST": 99.0,
#   'CLEMENTI AVE 6': 146.0,
#   'CLEMENTI ST 14': 150.0,
#   'CIRCUIT RD': 139.0,
#   'MACPHERSON LANE': 322.0,
#   'JLN PASAR BARU': 246.0,
#   'GEYLANG SERAI': 192.0,
#   'EUNOS CRES': 176.0,
#   'SIMS DR': 434.0,
#   'ALJUNIED CRES': 5.0,
#   'GEYLANG EAST AVE 1': 189.0,
#   'DAKOTA CRES': 163.0,
#   'PINE CL': 366.0,
#   'HAIG RD': 196.0,
#   'BALAM RD': 31.0,
#   'JLN DUA': 238.0,
#   'GEYLANG EAST CTRL': 191.0,
#   'EUNOS RD 5': 177.0,
#   'HOUGANG AVE 3': 208.0,
#   'HOUGANG AVE 5': 210.0,
#   'HOUGANG AVE 1': 205.0,
#   'HOUGANG ST 22': 218.0,
#   'HOUGANG AVE 10': 206.0,
#   'LOR AH SOO': 318.0,
#   'HOUGANG ST 11': 216.0,
#   'HOUGANG AVE 7': 212.0,
#   'HOUGANG ST 21': 217.0,
#   'TEBAN GDNS RD': 483.0,
#   'JURONG EAST AVE 1': 255.0,
#   'JURONG EAST ST 32': 260.0,
#   'JURONG EAST ST 13': 256.0,
#   'JURONG EAST ST 21': 257.0,
#   'JURONG EAST ST 24': 258.0,
#   'JURONG EAST ST 31': 259.0,
#   'PANDAN GDNS': 347.0,
#   'YUNG KUANG RD': 579.0,
#   'HO CHING RD': 201.0,
#   'HU CHING RD': 227.0,
#   'BOON LAY DR': 61.0,
#   'BOON LAY AVE': 60.0,
#   'BOON LAY PL': 62.0,
#   'JURONG WEST ST 52': 271.0,
#   'JURONG WEST ST 41': 268.0,
#   'JURONG WEST AVE 1': 261.0,
#   'JURONG WEST ST 42': 269.0,
#   'JLN BATU': 233.0,
#   "ST. GEORGE'S RD": 441.0,
#   'NTH BRIDGE RD': 342.0,
#   'FRENCH RD': 186.0,
#   'BEACH RD': 33.0,
#   'WHAMPOA DR': 514.0,
#   'UPP BOON KENG RD': 504.0,
#   'BENDEMEER RD': 51.0,
#   'WHAMPOA WEST': 517.0,
#   'LOR LIMAU': 320.0,
#   'KALLANG BAHRU': 285.0,
#   'GEYLANG BAHRU': 188.0,
#   'DORSET RD': 167.0,
#   'OWEN RD': 346.0,
#   'KG ARANG RD': 291.0,
#   'JLN BAHAGIA': 232.0,
#   'MOULMEIN RD': 338.0,
#   'TOWNER RD': 501.0,
#   'JLN RAJAH': 247.0,
#   'KENT RD': 290.0,
#   'AH HOOD RD': 2.0,
#   "KING GEORGE'S AVE": 300.0,
#   'CRAWFORD LANE': 162.0,
#   'MARINE CRES': 324.0,
#   'MARINE DR': 325.0,
#   'MARINE TER': 327.0,
#   "C'WEALTH CL": 100.0,
#   "C'WEALTH DR": 102.0,
#   'TANGLIN HALT RD': 481.0,
#   "C'WEALTH CRES": 101.0,
#   'DOVER RD': 170.0,
#   'MARGARET DR': 323.0,
#   'GHIM MOH RD': 194.0,
#   'DOVER CRES': 169.0,
#   'STIRLING RD': 442.0,
#   'MEI LING ST': 334.0,
#   'HOLLAND CL': 203.0,
#   'HOLLAND AVE': 202.0,
#   'HOLLAND DR': 204.0,
#   'DOVER CL EAST': 168.0,
#   'SELETAR WEST FARMWAY 6': 398.0,
#   'LOR LEW LIAN': 319.0,
#   'SERANGOON NTH AVE 1': 420.0,
#   'SERANGOON AVE 2': 415.0,
#   'SERANGOON AVE 4': 417.0,
#   'SERANGOON CTRL': 418.0,
#   'TAMPINES ST 11': 458.0,
#   'TAMPINES ST 21': 460.0,
#   'TAMPINES ST 91': 480.0,
#   'TAMPINES ST 81': 475.0,
#   'TAMPINES AVE 4': 450.0,
#   'TAMPINES ST 22': 461.0,
#   'TAMPINES ST 12': 459.0,
#   'TAMPINES ST 23': 462.0,
#   'TAMPINES ST 24': 463.0,
#   'TAMPINES ST 41': 467.0,
#   'TAMPINES ST 82': 476.0,
#   'TAMPINES ST 83': 477.0,
#   'TAMPINES AVE 5': 451.0,
#   'LOR 2 TOA PAYOH': 310.0,
#   'LOR 8 TOA PAYOH': 317.0,
#   'LOR 1 TOA PAYOH': 308.0,
#   'LOR 5 TOA PAYOH': 314.0,
#   'LOR 3 TOA PAYOH': 312.0,
#   'LOR 7 TOA PAYOH': 316.0,
#   'TOA PAYOH EAST': 497.0,
#   'LOR 4 TOA PAYOH': 313.0,
#   'TOA PAYOH CTRL': 496.0,
#   'TOA PAYOH NTH': 498.0,
#   'POTONG PASIR AVE 3': 370.0,
#   'POTONG PASIR AVE 1': 368.0,
#   'UPP ALJUNIED LANE': 503.0,
#   'JOO SENG RD': 254.0,
#   'MARSILING LANE': 330.0,
#   'MARSILING DR': 329.0,
#   'MARSILING RISE': 332.0,
#   'MARSILING CRES': 328.0,
#   'WOODLANDS CTR RD': 526.0,
#   'WOODLANDS ST 13': 545.0,
#   'WOODLANDS ST 11': 544.0,
#   'YISHUN RING RD': 563.0,
#   'YISHUN AVE 5': 557.0,
#   'YISHUN ST 72': 574.0,
#   'YISHUN ST 11': 564.0,
#   'YISHUN ST 21': 566.0,
#   'YISHUN ST 22': 567.0,
#   'YISHUN AVE 3': 555.0,
#   'CHAI CHEE AVE': 113.0,
#   'ZION RD': 583.0,
#   'LENGKOK BAHRU': 303.0,
#   'SPOTTISWOODE PK RD': 439.0,
#   'NEW MKT RD': 339.0,
#   'TG PAGAR PLAZA': 494.0,
#   'KELANTAN RD': 289.0,
#   'PAYA LEBAR WAY': 363.0,
#   'UBI AVE 1': 502.0,
#   'SIMS AVE': 433.0,
#   'YUNG PING RD': 581.0,
#   'TAO CHING RD': 482.0,
#   'GLOUCESTER RD': 195.0,
#   'BOON KENG RD': 59.0,
#   'WHAMPOA STH': 516.0,
#   'CAMBRIDGE RD': 103.0,
#   'TAMPINES ST 42': 468.0,
#   'LOR 6 TOA PAYOH': 315.0,
#   'KIM KEAT AVE': 295.0,
#   'YISHUN AVE 6': 558.0,
#   'YISHUN AVE 9': 560.0,
#   'YISHUN ST 71': 573.0,
#   'BT BATOK ST 32': 76.0,
#   'SILAT AVE': 426.0,
#   'TIONG BAHRU RD': 495.0,
#   'SAGO LANE': 394.0,
#   "ST. GEORGE'S LANE": 440.0,
#   'LIM CHU KANG RD': 305.0,
#   "C'WEALTH AVE": 98.0,
#   "QUEEN'S CL": 381.0,
#   'SERANGOON AVE 3': 416.0,
#   'POTONG PASIR AVE 2': 369.0,
#   'WOODLANDS AVE 1': 518.0,
#   'YISHUN AVE 4': 556.0,
#   'LOWER DELTA RD': 321.0,
#   'NILE RD': 341.0,
#   'JLN MEMBINA BARAT': 245.0,
#   'JLN BERSEH': 234.0,
#   'CHANDER RD': 117.0,
#   'CASSIA CRES': 112.0,
#   'OLD AIRPORT RD': 343.0,
#   'ALJUNIED RD': 6.0,
#   'BUANGKOK STH FARMWAY 1': 96.0,
#   'BT BATOK ST 33': 77.0,
#   'ALEXANDRA RD': 3.0,
#   'CHIN SWEE RD': 119.0,
#   'SIMS PL': 435.0,
#   'HOUGANG AVE 2': 207.0,
#   'HOUGANG AVE 8': 213.0,
#   'SEMBAWANG RD': 402.0,
#   'SIMEI ST 1': 429.0,
#   'BT BATOK ST 34': 78.0,
#   'BT MERAH CTRL': 88.0,
#   'LIM LIAK ST': 306.0,
#   'JLN TENTERAM': 251.0,
#   'WOODLANDS ST 32': 547.0,
#   'SIN MING AVE': 436.0,
#   'BT BATOK ST 52': 80.0,
#   'DELTA AVE': 165.0,
#   'PIPIT RD': 367.0,
#   'HOUGANG AVE 4': 209.0,
#   'QUEENSWAY': 383.0,
#   'YISHUN ST 61': 572.0,
#   'BISHAN ST 12': 54.0,
#   "JLN MA'MOR": 243.0,
#   'TAMPINES ST 44': 470.0,
#   'TAMPINES ST 43': 469.0,
#   'BISHAN ST 13': 55.0,
#   'JLN DUSUN': 239.0,
#   'YISHUN AVE 2': 554.0,
#   'JOO CHIAT RD': 253.0,
#   'EAST COAST RD': 171.0,
#   'REDHILL RD': 387.0,
#   'KIM PONG RD': 297.0,
#   'RACE COURSE RD': 384.0,
#   'KRETA AYER RD': 302.0,
#   'HOUGANG ST 61': 223.0,
#   'TESSENSOHN RD': 493.0,
#   'MARSILING RD': 331.0,
#   'YISHUN ST 81': 575.0,
#   'BT BATOK ST 51': 79.0,
#   'BT BATOK WEST AVE 4': 82.0,
#   'BT BATOK WEST AVE 2': 81.0,
#   'JURONG WEST ST 91': 282.0,
#   'JURONG WEST ST 81': 281.0,
#   'GANGSA RD': 187.0,
#   'MCNAIR RD': 333.0,
#   'SIMEI ST 4': 431.0,
#   'YISHUN AVE 7': 559.0,
#   'SERANGOON NTH AVE 2': 421.0,
#   'YISHUN AVE 11': 553.0,
#   'BANGKIT RD': 32.0,
#   'JURONG WEST ST 73': 278.0,
#   'OUTRAM HILL': 344.0,
#   'HOUGANG AVE 6': 211.0,
#   'PASIR RIS ST 12': 354.0,
#   'PENDING RD': 364.0,
#   'PETIR RD': 365.0,
#   'LOR 3 GEYLANG': 311.0,
#   'BISHAN ST 11': 53.0,
#   'PASIR RIS DR 6': 352.0,
#   'BISHAN ST 23': 57.0,
#   'JURONG WEST ST 92': 283.0,
#   'PASIR RIS ST 11': 353.0,
#   'YISHUN CTRL': 561.0,
#   'BISHAN ST 22': 56.0,
#   'SIMEI RD': 428.0,
#   'TAMPINES ST 84': 478.0,
#   'BT PANJANG RING RD': 91.0,
#   'JURONG WEST ST 93': 284.0,
#   'FAJAR RD': 179.0,
#   'WOODLANDS ST 81': 549.0,
#   'CHOA CHU KANG CTRL': 127.0,
#   'PASIR RIS ST 51': 358.0,
#   'HOUGANG ST 52': 222.0,
#   'CASHEW RD': 111.0,
#   'TOH YI DR': 500.0,
#   'HOUGANG CTRL': 215.0,
#   'KG KAYU RD': 293.0,
#   'TAMPINES AVE 8': 453.0,
#   'TAMPINES ST 45': 471.0,
#   'SIMEI ST 2': 430.0,
#   'WOODLANDS AVE 3': 519.0,
#   'LENGKONG TIGA': 304.0,
#   'WOODLANDS ST 82': 550.0,
#   'SERANGOON NTH AVE 4': 423.0,
#   'SERANGOON CTRL DR': 419.0,
#   'BRIGHT HILL DR': 64.0,
#   'SAUJANA RD': 395.0,
#   'CHOA CHU KANG AVE 3': 122.0,
#   'TAMPINES AVE 9': 454.0,
#   'JURONG WEST ST 51': 270.0,
#   'YUNG HO RD': 578.0,
#   'SERANGOON AVE 1': 414.0,
#   'PASIR RIS ST 41': 357.0,
#   'GEYLANG EAST AVE 2': 190.0,
#   'CHOA CHU KANG AVE 2': 121.0,
#   'KIM KEAT LINK': 296.0,
#   'PASIR RIS DR 4': 351.0,
#   'PASIR RIS ST 21': 356.0,
#   'SENG POH RD': 405.0,
#   'HOUGANG ST 51': 221.0,
#   'JURONG WEST ST 72': 277.0,
#   'JURONG WEST ST 71': 276.0,
#   'PASIR RIS ST 52': 359.0,
#   'TAMPINES ST 32': 464.0,
#   'CHOA CHU KANG AVE 4': 123.0,
#   'CHOA CHU KANG LOOP': 129.0,
#   'JLN TENAGA': 250.0,
#   'TAMPINES CTRL 1': 455.0,
#   'TAMPINES ST 33': 465.0,
#   'BT BATOK WEST AVE 7': 85.0,
#   'JURONG WEST AVE 5': 263.0,
#   'TAMPINES AVE 7': 452.0,
#   'WOODLANDS ST 83': 551.0,
#   'CHOA CHU KANG ST 51': 133.0,
#   'PASIR RIS DR 3': 350.0,
#   'YISHUN CTRL 1': 562.0,
#   'CHOA CHU KANG AVE 1': 120.0,
#   'WOODLANDS ST 31': 546.0,
#   'BT MERAH LANE 1': 89.0,
#   'PASIR RIS ST 13': 355.0,
#   'ELIAS RD': 174.0,
#   'BISHAN ST 24': 58.0,
#   'WHAMPOA RD': 515.0,
#   'WOODLANDS ST 41': 548.0,
#   'PASIR RIS ST 71': 361.0,
#   'JURONG WEST ST 74': 279.0,
#   'PASIR RIS DR 1': 348.0,
#   'PASIR RIS ST 72': 362.0,
#   'PASIR RIS DR 10': 349.0,
#   'CHOA CHU KANG ST 52': 134.0,
#   'CLARENCE LANE': 140.0,
#   'CHOA CHU KANG NTH 6': 131.0,
#   'PASIR RIS ST 53': 360.0,
#   'CHOA CHU KANG NTH 5': 130.0,
#   'ANG MO KIO ST 21': 23.0,
#   'JLN DAMAI': 237.0,
#   'CHOA CHU KANG ST 62': 137.0,
#   'WOODLANDS AVE 5': 521.0,
#   'WOODLANDS DR 50': 532.0,
#   'CHOA CHU KANG ST 53': 135.0,
#   'TAMPINES ST 72': 474.0,
#   'UPP SERANGOON RD': 507.0,
#   'JURONG WEST ST 75': 280.0,
#   'STRATHMORE AVE': 443.0,
#   'ANG MO KIO ST 31': 24.0,
#   'TAMPINES ST 34': 466.0,
#   'YUNG AN RD': 577.0,
#   'WOODLANDS AVE 4': 520.0,
#   'CHOA CHU KANG NTH 7': 132.0,
#   'ANG MO KIO ST 11': 22.0,
#   'WOODLANDS AVE 9': 523.0,
#   'YUNG LOH RD': 580.0,
#   'CHOA CHU KANG DR': 128.0,
#   'CHOA CHU KANG ST 54': 136.0,
#   'REDHILL LANE': 386.0,
#   'KANG CHING RD': 286.0,
#   'TAH CHING RD': 447.0,
#   'SIMEI ST 5': 432.0,
#   'WOODLANDS DR 40': 529.0,
#   'WOODLANDS DR 70': 537.0,
#   'TAMPINES ST 71': 473.0,
#   'WOODLANDS DR 42': 530.0,
#   'SERANGOON NTH AVE 3': 422.0,
#   'JELAPANG RD': 229.0,
#   'BT BATOK ST 22': 72.0,
#   'HOUGANG ST 91': 224.0,
#   'WOODLANDS AVE 6': 522.0,
#   'WOODLANDS CIRCLE': 524.0,
#   'CORPORATION DR': 161.0,
#   'LOMPANG RD': 307.0,
#   'WOODLANDS DR 72': 539.0,
#   'CHOA CHU KANG ST 64': 138.0,
#   'BT BATOK ST 24': 73.0,
#   'JLN TECK WHYE': 249.0,
#   'WOODLANDS CRES': 525.0,
#   'WOODLANDS DR 60': 535.0,
#   'CHANGI VILLAGE RD': 118.0,
#   'BT BATOK ST 25': 74.0,
#   'HOUGANG AVE 9': 214.0,
#   'JURONG WEST CTRL 1': 264.0,
#   'WOODLANDS RING RD': 542.0,
#   'CHOA CHU KANG AVE 5': 124.0,
#   'TOH GUAN RD': 499.0,
#   'JURONG WEST ST 61': 272.0,
#   'WOODLANDS DR 14': 527.0,
#   'HOUGANG ST 92': 225.0,
#   'CHOA CHU KANG CRES': 126.0,
#   'SEMBAWANG CL': 399.0,
#   'CANBERRA RD': 106.0,
#   'SEMBAWANG CRES': 400.0,
#   'SEMBAWANG VISTA': 403.0,
#   'COMPASSVALE WALK': 160.0,
#   'RIVERVALE ST': 390.0,
#   'WOODLANDS DR 62': 536.0,
#   'SEMBAWANG DR': 401.0,
#   'WOODLANDS DR 53': 534.0,
#   'WOODLANDS DR 52': 533.0,
#   'RIVERVALE WALK': 391.0,
#   'COMPASSVALE LANE': 156.0,
#   'RIVERVALE DR': 389.0,
#   'SENJA RD': 413.0,
#   'JURONG WEST ST 65': 275.0,
#   'RIVERVALE CRES': 388.0,
#   'WOODLANDS DR 44': 531.0,
#   'COMPASSVALE DR': 155.0,
#   'WOODLANDS DR 16': 528.0,
#   'COMPASSVALE RD': 158.0,
#   'WOODLANDS DR 73': 540.0,
#   'HOUGANG ST 31': 219.0,
#   'JURONG WEST ST 64': 274.0,
#   'WOODLANDS DR 71': 538.0,
#   'YISHUN ST 20': 565.0,
#   'ADMIRALTY DR': 0.0,
#   'COMPASSVALE ST': 159.0,
#   'BEDOK RESERVOIR VIEW': 46.0,
#   'YUNG SHENG RD': 582.0,
#   'ADMIRALTY LINK': 1.0,
#   'SENGKANG EAST WAY': 409.0,
#   'ANG MO KIO ST 32': 25.0,
#   'ANG MO KIO ST 52': 28.0,
#   'BOON TIONG RD': 63.0,
#   'JURONG WEST ST 62': 273.0,
#   'ANCHORVALE LINK': 10.0,
#   'CANBERRA LINK': 105.0,
#   'COMPASSVALE CRES': 154.0,
#   'CLEMENTI ST 12': 148.0,
#   'MONTREAL DR': 336.0,
#   'WELLINGTON CIRCLE': 511.0,
#   'SENGKANG EAST RD': 408.0,
#   'JURONG WEST AVE 3': 262.0,
#   'ANCHORVALE LANE': 9.0,
#   'SENJA LINK': 412.0,
#   'EDGEFIELD PLAINS': 173.0,
#   'ANCHORVALE DR': 8.0,
#   'SEGAR RD': 396.0,
#   'FARRER PK RD': 180.0,
#   'PUNGGOL FIELD': 374.0,
#   'EDGEDALE PLAINS': 172.0,
#   'ANCHORVALE RD': 11.0,
#   'CANTONMENT CL': 109.0,
#   'JLN MEMBINA': 244.0,
#   'FERNVALE LANE': 182.0,
#   'JURONG WEST ST 25': 267.0,
#   'CLEMENTI ST 11': 147.0,
#   'PUNGGOL FIELD WALK': 375.0,
#   'KLANG LANE': 301.0,
#   'PUNGGOL CTRL': 371.0,
#   'JELEBU RD': 230.0,
#   'BUANGKOK CRES': 93.0,
#   'WOODLANDS DR 75': 541.0,
#   'BT BATOK WEST AVE 5': 83.0,
#   'JELLICOE RD': 231.0,
#   'PUNGGOL DR': 372.0,
#   'JURONG WEST ST 24': 266.0,
#   'SEMBAWANG WAY': 404.0,
#   'FERNVALE RD': 184.0,
#   'BUANGKOK LINK': 95.0,
#   'FERNVALE LINK': 183.0,
#   'JLN TIGA': 252.0,
#   'YUAN CHING RD': 576.0,
#   'COMPASSVALE LINK': 157.0,
#   'MARINE PARADE CTRL': 326.0,
#   'COMPASSVALE BOW': 153.0,
#   'PUNGGOL RD': 377.0,
#   'BEDOK CTRL': 34.0,
#   'PUNGGOL EAST': 373.0,
#   'SENGKANG CTRL': 406.0,
#   'TAMPINES CTRL 7': 456.0,
#   'SENGKANG WEST AVE': 410.0,
#   'PUNGGOL PL': 376.0,
#   'CANTONMENT RD': 110.0,
#   'GHIM MOH LINK': 193.0,
#   'SIMEI LANE': 427.0,
#   'YISHUN ST 41': 569.0,
#   'TELOK BLANGAH ST 31': 491.0,
#   'JLN KAYU': 240.0,
#   'LOR 1A TOA PAYOH': 309.0,
#   'PUNGGOL WALK': 378.0,
#   'SENGKANG WEST WAY': 411.0,
#   'BUANGKOK GREEN': 94.0,
#   'PUNGGOL WAY': 379.0,
#   'YISHUN ST 31': 568.0,
#   'TECK WHYE CRES': 485.0,
#   'MONTREAL LINK': 337.0,
#   'UPP SERANGOON CRES': 506.0,
#   'SUMANG LINK': 445.0,
#   'SENGKANG EAST AVE': 407.0,
#   'YISHUN AVE 1': 552.0,
#   'ANCHORVALE CRES': 7.0,
#   'ANCHORVALE ST': 12.0,
#   'TAMPINES CTRL 8': 457.0,
#   'YISHUN ST 51': 571.0,
#   'UPP SERANGOON VIEW': 508.0,
#   'TAMPINES AVE 1': 449.0,
#   'BEDOK RESERVOIR CRES': 44.0,
#   'ANG MO KIO ST 61': 29.0,
#   'DAWSON RD': 164.0,
#   'FERNVALE ST': 185.0,
#   'HOUGANG ST 32': 220.0,
#   'TAMPINES ST 86': 479.0,
#   'SUMANG WALK': 446.0,
#   'CHOA CHU KANG AVE 7': 125.0,
#   'KEAT HONG CL': 287.0,
#   'JURONG WEST CTRL 3': 265.0,
#   'KEAT HONG LINK': 288.0,
#   'ALJUNIED AVE 2': 4.0,
#   'CANBERRA CRES': 104.0,
#   'SUMANG LANE': 444.0,
#   'CANBERRA ST': 107.0,
#   'ANG MO KIO ST 44': 26.0,
#   'WOODLANDS RISE': 543.0,
#   'CANBERRA WALK': 108.0,
#   'ANG MO KIO ST 51': 27.0,
#   'BT BATOK EAST AVE 6': 69.0,
#   'BT BATOK WEST AVE 9': 87.0,
#   'TAMPINES ST 61': 472.0,
#   'YISHUN ST 43': 570.0},
#  'storey_range': {'10 TO 12': 5.0,
#   '04 TO 06': 2.0,
#   '07 TO 09': 4.0,
#   '01 TO 03': 0.0,
#   '13 TO 15': 7.0,
#   '19 TO 21': 10.0,
#   '16 TO 18': 8.0,
#   '25 TO 27': 13.0,
#   '22 TO 24': 12.0,
#   '28 TO 30': 15.0,
#   '31 TO 33': 16.0,
#   '40 TO 42': 21.0,
#   '37 TO 39': 20.0,
#   '34 TO 36': 18.0,
#   '06 TO 10': 3.0,
#   '01 TO 05': 1.0,
#   '11 TO 15': 6.0,
#   '16 TO 20': 9.0,
#   '21 TO 25': 11.0,
#   '26 TO 30': 14.0,
#   '36 TO 40': 19.0,
#   '31 TO 35': 17.0,
#   '46 TO 48': 23.0,
#   '43 TO 45': 22.0,
#   '49 TO 51': 24.0},
#  'flat_model': {'IMPROVED': 5.0,
#   'NEW GENERATION': 12.0,
#   'MODEL A': 8.0,
#   'STANDARD': 17.0,
#   'SIMPLIFIED': 16.0,
#   'MODEL A-MAISONETTE': 9.0,
#   'APARTMENT': 3.0,
#   'MAISONETTE': 7.0,
#   'TERRACE': 18.0,
#   '2-ROOM': 0.0,
#   'IMPROVED-MAISONETTE': 6.0,
#   'MULTI GENERATION': 11.0,
#   'PREMIUM APARTMENT': 13.0,
#   'ADJOINED FLAT': 2.0,
#   'PREMIUM MAISONETTE': 15.0,
#   'MODEL A2': 10.0,
#   'DBSS': 4.0,
#   'TYPE S1': 19.0,
#   'TYPE S2': 20.0,
#   'PREMIUM APARTMENT LOFT': 14.0,
#   '3GEN': 1.0},
#  'remaining': {'Not Specified': 771.0,
#   '70.0': 395.0,
#   '65.0': 324.0,
#   '64.0': 310.0,
#   '63.0': 296.0,
#   '62.0': 282.0,
#   '69.0': 381.0,
#   '60.0': 254.0,
#   '61.0': 268.0,
#   '86.0': 619.0,
#   '77.0': 493.0,
#   '80.0': 535.0,
#   '90.0': 675.0,
#   '87.0': 633.0,
#   '66.0': 339.0,
#   '58.0': 226.0,
#   '94.0': 732.0,
#   '71.0': 409.0,
#   '68.0': 367.0,
#   '84.0': 591.0,
#   '73.0': 437.0,
#   '79.0': 521.0,
#   '76.0': 479.0,
#   '72.0': 423.0,
#   '82.0': 563.0,
#   '74.0': 451.0,
#   '67.0': 353.0,
#   '88.0': 647.0,
#   '81.0': 549.0,
#   '89.0': 661.0,
#   '53.0': 156.0,
#   '54.0': 170.0,
#   '55.0': 184.0,
#   '57.0': 212.0,
#   '93.0': 718.0,
#   '83.0': 577.0,
#   '85.0': 605.0,
#   '92.0': 703.0,
#   '91.0': 689.0,
#   '59.0': 240.0,
#   '95.0': 747.0,
#   '52.0': 142.0,
#   '51.0': 128.0,
#   '56.0': 198.0,
#   '75.0': 465.0,
#   '96.0': 761.0,
#   '78.0': 507.0,
#   '50.0': 114.0,
#   '97.0': 770.0,
#   '67': 340.0,
#   '66': 325.0,
#   '70': 382.0,
#   '71': 396.0,
#   '68': 354.0,
#   '81': 536.0,
#   '88': 634.0,
#   '76': 466.0,
#   '58': 213.0,
#   '53': 143.0,
#   '57': 199.0,
#   '62': 269.0,
#   '59': 227.0,
#   '50': 101.0,
#   '54': 157.0,
#   '56': 185.0,
#   '60': 241.0,
#   '52': 129.0,
#   '86': 606.0,
#   '69': 368.0,
#   '78': 494.0,
#   '80': 522.0,
#   '92': 690.0,
#   '89': 648.0,
#   '87': 620.0,
#   '61': 255.0,
#   '63': 283.0,
#   '64': 297.0,
#   '83': 564.0,
#   '72': 410.0,
#   '73': 424.0,
#   '82': 550.0,
#   '85': 592.0,
#   '94': 719.0,
#   '75': 452.0,
#   '77': 480.0,
#   '79': 508.0,
#   '65': 311.0,
#   '95': 733.0,
#   '90': 662.0,
#   '74': 438.0,
#   '91': 676.0,
#   '84': 578.0,
#   '93': 704.0,
#   '55': 171.0,
#   '96': 748.0,
#   '51': 115.0,
#   '49': 88.0,
#   '48': 75.0,
#   '61 years 04 months': 260.0,
#   '60 years 07 months': 249.0,
#   '62 years 05 months': 275.0,
#   '62 years 01 month': 271.0,
#   '63 years': 284.0,
#   '61 years 06 months': 262.0,
#   '58 years 04 months': 218.0,
#   '59 years 08 months': 236.0,
#   '59 years 06 months': 234.0,
#   '60 years': 242.0,
#   '62 years 08 months': 278.0,
#   '61 years': 256.0,
#   '60 years 10 months': 252.0,
#   '59 years 03 months': 231.0,
#   '61 years 05 months': 261.0,
#   '60 years 04 months': 246.0,
#   '62 years': 270.0,
#   '60 years 03 months': 245.0,
#   '63 years 09 months': 293.0,
#   '61 years 01 month': 257.0,
#   '61 years 10 months': 266.0,
#   '58 years 06 months': 220.0,
#   '59 years 04 months': 232.0,
#   '62 years 11 months': 281.0,
#   '60 years 08 months': 250.0,
#   '93 years 08 months': 714.0,
#   '93 years 07 months': 713.0,
#   '60 years 01 month': 243.0,
#   '94 years 08 months': 728.0,
#   '78 years 04 months': 499.0,
#   '60 years 06 months': 248.0,
#   '62 years 06 months': 276.0,
#   '58 years': 214.0,
#   '70 years 08 months': 391.0,
#   '47 years 02 months': 65.0,
#   '47 years 03 months': 66.0,
#   '47 years 01 month': 64.0,
#   '47 years': 63.0,
#   '46 years 11 months': 62.0,
#   '46 years 10 months': 61.0,
#   '46 years 09 months': 60.0,
#   '46 years 08 months': 59.0,
#   '66 years 0 months': 327.0,
#   '95 years 0 months': 735.0,
#   '46 years 07 months': 58.0,
#   '46 years 06 months': 57.0,
#   '46 years 03 months': 54.0,
#   '93 years 0 months': 706.0,
#   '46 years 05 months': 56.0,
#   '46 years 04 months': 55.0,
#   '46 years 01 month': 52.0,
#   '46 years 02 months': 53.0,
#   '46 years': 51.0,
#   '45 years 09 months': 48.0,
#   '45 years 11 months': 50.0,
#   '45 years 10 months': 49.0,
#   '45 years 07 months': 46.0,
#   '45 years 08 months': 47.0,
#   '97 years 01 month': 763.0,
#   '45 years 06 months': 45.0,
#   '97 years 09 months': 769.0,
#   '45 years 05 months': 44.0,
#   '45 years 04 months': 43.0,
#   '97 years': 762.0,
#   '97 years 07 months': 768.0,
#   '45 years 03 months': 42.0,
#   '45 years 02 months': 41.0,
#   '96 years 09 months': 758.0,
#   '45 years 01 month': 40.0,
#   '44 years 10 months': 37.0,
#   '97 years 05 months': 767.0,
#   '97 years 04 months': 766.0,
#   '45 years': 39.0,
#   '44 years 11 months': 38.0,
#   '97 years 03 months': 765.0,
#   '97 years 02 months': 764.0,
#   '44 years 09 months': 36.0,
#   '44 years 08 months': 35.0,
#   '96 years 11 months': 760.0,
#   '44 years 07 months': 34.0,
#   '44 years 06 months': 33.0,
#   '96 years 10 months': 759.0,
#   '44 years 05 months': 32.0,
#   '44 years 04 months': 31.0,
#   '44 years 03 months': 30.0,
#   '44 years 01 month': 28.0,
#   '44 years 02 months': 29.0,
#   '44 years': 27.0,
#   '43 years 11 months': 26.0,
#   '43 years 10 months': 25.0,
#   '43 years 09 months': 24.0,
#   '43 years 08 months': 23.0,
#   '43 years 07 months': 22.0,
#   '43 years 06 months': 21.0,
#   '43 years 05 months': 20.0,
#   '43 years 04 months': 19.0,
#   '43 years 03 months': 18.0,
#   '43 years 01 month': 16.0,
#   '43 years 02 months': 17.0,
#   '43 years': 15.0,
#   '42 years 11 months': 14.0,
#   '42 years 08 months': 11.0,
#   '42 years 07 months': 10.0,
#   '42 years 10 months': 13.0,
#   '42 years 09 months': 12.0,
#   '42 years 06 months': 9.0,
#   '42 years 05 months': 8.0,
#   '42 years 04 months': 7.0,
#   '42 years 03 months': 6.0,
#   '42 years 02 months': 5.0,
#   '42 years 01 month': 4.0,
#   '41 years 11 months': 2.0,
#   '41 years 10 months': 1.0,
#   '41 years 09 months': 0.0,
#   '42 years': 3.0}}

# %%
import json
# Write the unique_value dictionary to a JSON file with proper indentation
with open('Category_Columns_Encoded_Data.json', 'w') as file:
    json.dump(unique_value, file , indent = 4)

# %%
df1.dtypes
# Out:
# month                    int64
# town                   float64
# flat_type              float64
# block                  float64
# street_name            float64
# storey_range           float64
# floor_area_sqm         float64
# flat_model             float64
# lease_commence_date      int64
# remaining              float64
# resale_price           float64
# year                     int64
# minimum_storey           int32
# maximum_storey           int32
# is_remaining_lease       int32
# floor_area_sqm_sqrt    float64
# resale_price_sqrt      float64
# dtype: object

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import HistGradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error,  r2_score

# %%
class regression:

    def __init__(self, x, y):
        # List of regression models to be evaluated
        self.models =[('AdaBoostRegressor', AdaBoostRegressor()),
                    #  ('RandomForestRegressor', RandomForestRegressor()),
                    #  ('ExtraTreesRegressor', ExtraTreesRegressor()),
                     ('GradientBoostingRegressor', GradientBoostingRegressor()),
                     ('HistGradientBoostingRegressor', HistGradientBoostingRegressor()),
                     ('DecisionTreeRegressor', DecisionTreeRegressor()),
                     ('XGBRegressor', XGBRegressor()),
                     ('LinearRegression', LinearRegression()),
                     ('KNeighborsRegressor', KNeighborsRegressor()),
                     ('MLPRegressor', MLPRegressor()),
                     ]
        # Split the data into training and testing sets
        self.x_train, self.x_test, self.y_train,self.y_test = train_test_split(x,y,test_size=0.2, random_state = 42)
    
    def all_model(self):
        # Train and evaluate each model
        print(self.x_train.shape, self.x_test.shape, self.y_train.shape, self.y_test.shape)
        result = []
        for model_name, model in self.models:
            model.fit(self.x_train, self.y_train)
            y_test_pred = model.predict(self.x_test)
            y_train_pred = model.predict(self.x_train)
            
            data ={'Model_Name': model_name,
                    'Train_Mean_Square_Error': round(mean_squared_error(self.y_train, y_train_pred),4),
                    'Test_Mean_Square_Error': round(mean_squared_error(self.y_test, y_test_pred),4),
                    'Train_Mean_Absolute_Error': round(mean_absolute_error(self.y_train, y_train_pred),4),
                    'Test_Mean_Absolute_Error': round(mean_absolute_error(self.y_test, y_test_pred),4),
                    'Train_R2_Score': round(r2_score(self.y_train, y_train_pred ),4),
                    'Test_R2_Score': round(r2_score(self.y_test, y_test_pred), 4)}
            result.append(data)
            
        self.model_score_df = pd.DataFrame(result)

        return self.model_score_df

# %%
#y is the target variable, containing the 'resale_price_sqrt' values.
#x is the feature set, containing all columns from df1 except 'resale_price_sqrt' and 'resale_price'.

y = df1['resale_price_sqrt']
x = df1.drop(['resale_price_sqrt', 'resale_price'], axis =1)

# %%
# Create an instance of the 'regression' class with input features 'x' and target variable 'y'
regression_models = regression(x,y)
# Apply the 'all_model' method to train and evaluate various regression models
r_models = regression_models.all_model()
r_models
# Out:
# (740711, 15) (185178, 15) (740711,) (185178,)
# C:\Users\mahes\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
#                       Model_Name  Train_Mean_Square_Error  \
# 0              AdaBoostRegressor                4096.7540
# 1      GradientBoostingRegressor                1450.2762
# 2  HistGradientBoostingRegressor                 632.6339
# 3          DecisionTreeRegressor                   4.1759
# 4                   XGBRegressor                 396.2225
# 5               LinearRegression                4320.5407
# 6            KNeighborsRegressor                1164.6555
# 7                   MLPRegressor                4110.5445
#
#    Test_Mean_Square_Error  Train_Mean_Absolute_Error  \
# 0               4116.9759                    51.5835
# 1               1452.0143                    28.1437
# 2                634.7440                    18.8477
# 3                611.4189                     0.3177
# 4                404.6789                    14.8594
# 5               4331.5996                    51.6983
# 6               1833.0806                    23.6534
# 7               4122.3098                    49.8881
#
#    Test_Mean_Absolute_Error  Train_R2_Score  Test_R2_Score
# 0                   51.7134          0.8182         0.8168
# 1                   28.1902          0.9356         0.9354
# 2                   18.8683          0.9719         0.9718
# 3                   17.3347          0.9998         0.9728
# 4                   14.9743          0.9824         0.9820
# 5                   51.7543          0.8082         0.8073
# 6                   29.7634          0.9483         0.9184
# 7                   49.9419          0.8175         0.8166

# %%
r_models['Train_Mean_Square_Error'] - r_models['Test_Mean_Square_Error'],
# Out:
# (0    -20.2219
#  1     -1.7381
#  2     -2.1101
#  3   -607.2430
#  4     -8.4564
#  5    -11.0589
#  6   -668.4251
#  7    -11.7653
#  dtype: float64,)

# %%
# Extract the training and testing sets from the instance for further analysis
x_train, x_test, y_train, y_test = regression_models.x_train, regression_models.x_test, regression_models.y_train, regression_models.y_test
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((740711, 15), (185178, 15), (740711,), (185178,))

# %%
# XGBRegressor 
model = XGBRegressor()
model.fit(x_train, y_train)
y_test_pred = model.predict(x_test)
y_train_pred = model.predict(x_train)
data ={
        'Train_Mean_Square_Error': round(mean_squared_error(y_train, y_train_pred),4),
        'Test_Mean_Square_Error': round(mean_squared_error(y_test, y_test_pred),4)}
print(data)
# Out:
# {'Train_Mean_Square_Error': 396.2225, 'Test_Mean_Square_Error': 404.6789}

# %%
# Hyperparameter tuning for XGBRegressor

# Define the parameter grid
param_grid = {
    'learning_rate': [0.1, 0.01, 0.001],
    'max_depth': [3, 4, 5],
    'n_estimators': [50, 100, 200]
}

# Create the XGBRegressor
xgb_reg = XGBRegressor()

# Use GridSearchCV to perform the search
grid_search = GridSearchCV(estimator=xgb_reg, param_grid=param_grid, scoring='neg_mean_squared_error', cv=3)
grid_result = grid_search.fit(x_train, y_train)

# Get the best parameters and the best model
best_params = grid_result.best_params_
best_model = grid_result.best_estimator_

# Evaluate the best model on the test set
y_pred = best_model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error on Test Set: {mse}')
best_params
# Out:
# Mean Squared Error on Test Set: 550.9377306483731
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}

# %%
# XBGRegressore with Hyperparameter
xgb_model = XGBRegressor(learning_rate = 0.1, max_depth = 5, n_estimators = 200)
xgb_model.fit(x_train, y_train)

y_pred = xgb_model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae=mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

score ={'R2': r2,
        'Mean Absolute Error': mae,
        'Mean Squared Error': mse,
        'Root Mean Squared Error': rmse}
print(score)
# Out:
# {'R2': 0.975488924697025, 'Mean Absolute Error': 17.4765737788136, 'Mean Squared Error': 550.9377306483731, 'Root Mean Squared Error': 23.47206276935142}

# %%
# DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(x_train, y_train)
y_test_pred = model.predict(x_test)
y_train_pred = model.predict(x_train)
data ={
        'Train_Mean_Square_Error': round(mean_squared_error(y_train, y_train_pred),4),
        'Test_Mean_Square_Error': round(mean_squared_error(y_test, y_test_pred),4)}
print(data)
# Out:
# {'Train_Mean_Square_Error': 4.1759, 'Test_Mean_Square_Error': 609.0436}

# %%
# Hyperparameter tuning
# Define the parameter grid
param_grid = {
    'max_depth': [None, 5, 10, 15],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Create the DecisionTreeRegressor
tree_reg = DecisionTreeRegressor(random_state=42)

# Use GridSearchCV to perform the search
grid_search = GridSearchCV(estimator=tree_reg, param_grid=param_grid, scoring='neg_mean_squared_error', cv=3)
grid_result = grid_search.fit(x_train, y_train)

# Get the best parameters and the best model
best_params = grid_result.best_params_
best_model = grid_result.best_estimator_

# Evaluate the best model on the test set
y_pred = best_model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error on Test Set: {mse}')
print(best_model, best_params)
# Out:
# Mean Squared Error on Test Set: 484.90941637068477
# DecisionTreeRegressor(min_samples_leaf=4, min_samples_split=10, random_state=42) {'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 10}

# %%
# DecisionTreeRegressor with Hyperparameter
decision_tree_model = DecisionTreeRegressor(min_samples_leaf=4, min_samples_split=10,)
decision_tree_model.fit(x_train, y_train)
y_pred = decision_tree_model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae=mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

score ={'R2': r2,
        'Mean Absolute Error': mae,
        'Mean Squared Error': mse,
        'Root Mean Squared Error': rmse}
print(score)
# Out:
# {'R2': 0.9784449402521985, 'Mean Absolute Error': 15.44458207415222, 'Mean Squared Error': 484.4950927143717, 'Root Mean Squared Error': 22.01124923111752}

# %%
# Resale Price Prediction
data = np.array([[11, 1.0,4.0, 286.0, 39, 4.0,110.0, 5.0, 2006.0, 719, 2009.0, 7.0, 9.0, 0.0, 10.488]])
data.shape
print('XGBRegressor -> Resale Price : $', xgb_model.predict(data)[0]**2)
print('DecisionTreeRegressor -> Resale Price : $', decision_tree_model.predict(data)[0]**2)
# Out:
# XGBRegressor -> Resale Price : $ 509655.3363645226
# DecisionTreeRegressor -> Resale Price : $ 492472.31149089994
# C:\Users\mahes\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
column_name = ['month', 'town', 'flat_type', 'block', 'street_name', 'storey_range', 'floor_area_sqm', 'flat_model', 'lease_commence_date',
                'remaining', 'year', 'minimum_storey', 'maximum_storey', 'is_remaining_lease', 'floor_area_sqm_sqrt', ]
test_data =df1.iloc[0: :50000][column_name].values
test_result = df1.iloc[0: :50000][['resale_price']]
dt_y=decision_tree_model.predict(test_data)**2
xgb_y = xgb_model.predict(test_data)**2
# Out:
# C:\Users\mahes\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
# Comparing Predicted DecisionTreeRegressor, XGBRegressor resale price with Actual resale price
pred =pd.DataFrame(zip(df1.iloc[0: :50000]['resale_price'], dt_y, xgb_y), columns= ['Actual_resale_price', 'DecisionTreeRegressor', 'XGBRegressor'])
pred['XGBRegressor_Difference'] = pred['XGBRegressor'] - pred['Actual_resale_price']
pred['DecisionTreeRegressor_Difference'] = pred['DecisionTreeRegressor'] - pred['Actual_resale_price']
pred
# Out:
#     Actual_resale_price  DecisionTreeRegressor   XGBRegressor  \
# 0                9000.0           16811.994206   16527.273438
# 1               77000.0           73432.280004   73243.156250
# 2              388000.0          310997.984032  383758.937500
# 3              163000.0          155899.113036  145078.968750
# 4              197500.0          188587.797712  191684.062500
# 5              235000.0          257053.823526  239543.328125
# 6              248000.0          262748.652267  257214.203125
# 7              255000.0          274205.645263  295448.312500
# 8              227000.0          228788.557447  238197.078125
# 9              245000.0          242249.641968  235429.750000
# 10             250000.0          254365.486919  261813.578125
# 11             390000.0          398046.326209  380542.437500
# 12             331000.0          336600.301293  353039.281250
# 13             455000.0          437905.937563  422212.656250
# 14             305000.0          290564.603175  316398.281250
# 15             433000.0          434892.551257  435961.000000
# 16             368000.0          379303.221607  372017.812500
# 17             295000.0          317375.500329  309647.468750
# 18             480000.0          469306.649872  470274.562500
#
#     XGBRegressor_Difference  DecisionTreeRegressor_Difference
# 0               7527.273438                       7811.994206
# 1              -3756.843750                      -3567.719996
# 2              -4241.062500                     -77002.015968
# 3             -17921.031250                      -7100.886964
# 4              -5815.937500                      -8912.202288
# 5               4543.328125                      22053.823526
# 6               9214.203125                      14748.652267
# 7              40448.312500                      19205.645263
# 8              11197.078125                       1788.557447
# 9              -9570.250000                      -2750.358032
# 10             11813.578125                       4365.486919
# 11             -9457.562500                       8046.326209
# 12             22039.281250                       5600.301293
# 13            -32787.343750                     -17094.062437
# 14             11398.281250                     -14435.396825
# 15              2961.000000                       1892.551257
# 16              4017.812500                      11303.221607
# 17             14647.468750                      22375.500329
# 18             -9725.437500                     -10693.350128

# %%
# With help of above dataframe DecisionTreeRegressor's predicted resale price is near to the Actual resale price. That's I am going to choose 'DecisionTreeRegressor' for resale price prediction
# Save the Decision Tree model to a file
import pickle

with open('Decision_Tree_Model.pkl', 'wb') as file:
    pickle.dump(decision_tree_model, file)

# %%
# Load the Decision Tree model from the file
with open('Decision_Tree_Model.pkl', 'rb' ) as file:
    reg_model = pickle.load(file)

# %%
# Make a prediction using the loaded model
data = np.array([[11, 1.0,4.0, 286.0, 39, 4.0,110.0, 5.0, 2006.0, 719, 2009.0, 7.0, 9.0, 0.0, 10.488]])

print( 'Resale Price : $', reg_model.predict(data)[0]**2)
# Out:
# Resale Price : $ 492472.31149089994
# C:\Users\mahes\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
